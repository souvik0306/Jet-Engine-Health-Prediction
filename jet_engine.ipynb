# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('NASA-s-Turbo-Engine-Remaining-Useful-Life-prediction-using-machine-learning-main\Training_1_all_features.csv')

# %%
data_frame.shape
# Out:
# (20631, 26)

# %%
data_frame.head()
# Out:
#    Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 0      1 -0.0007 -0.0004   100.0          518.67          641.82
# 1      2  0.0019 -0.0003   100.0          518.67          642.15
# 2      3 -0.0043  0.0003   100.0          518.67          642.35
# 3      4  0.0007  0.0000   100.0          518.67          642.35
# 4      5 -0.0019 -0.0002   100.0          518.67          642.37
#
#    SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# 0         1589.70         1400.60           14.62           21.61  ...
# 1         1591.82         1403.14           14.62           21.61  ...
# 2         1587.99         1404.20           14.62           21.61  ...
# 3         1582.79         1401.87           14.62           21.61  ...
# 4         1582.85         1406.22           14.62           21.61  ...
#
#    SensorMeasure13  SensorMeasure14  SensorMeasure15  SensorMeasure16  \
# 0          2388.02          8138.62           8.4195             0.03
# 1          2388.07          8131.49           8.4318             0.03
# 2          2388.03          8133.23           8.4178             0.03
# 3          2388.08          8133.83           8.3682             0.03
# 4          2388.04          8133.80           8.4294             0.03
#
#    SensorMeasure17  SensorMeasure18  SensorMeasure19  SensorMeasure20  \
# 0              392             2388            100.0            39.06
# 1              392             2388            100.0            39.00
# 2              390             2388            100.0            38.95
# 3              392             2388            100.0            38.88
# 4              393             2388            100.0            38.90
#
#    SensorMeasure21  labels
# 0          23.4190       0
# 1          23.4236       0
# 2          23.3442       0
# 3          23.3739       0
# 4          23.4044       0
#
# [5 rows x 26 columns]

# %%
data_frame.tail()
# Out:
#        Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 20626    196 -0.0004 -0.0003   100.0          518.67          643.49
# 20627    197 -0.0016 -0.0005   100.0          518.67          643.54
# 20628    198  0.0004  0.0000   100.0          518.67          643.42
# 20629    199 -0.0011  0.0003   100.0          518.67          643.23
# 20630    200 -0.0032 -0.0005   100.0          518.67          643.85
#
#        SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# 20626         1597.98         1428.63           14.62           21.61  ...
# 20627         1604.50         1433.58           14.62           21.61  ...
# 20628         1602.46         1428.18           14.62           21.61  ...
# 20629         1605.26         1426.53           14.62           21.61  ...
# 20630         1600.38         1432.14           14.62           21.61  ...
#
#        SensorMeasure13  SensorMeasure14  SensorMeasure15  SensorMeasure16  \
# 20626          2388.26          8137.60           8.4956             0.03
# 20627          2388.22          8136.50           8.5139             0.03
# 20628          2388.24          8141.05           8.5646             0.03
# 20629          2388.23          8139.29           8.5389             0.03
# 20630          2388.26          8137.33           8.5036             0.03
#
#        SensorMeasure17  SensorMeasure18  SensorMeasure19  SensorMeasure20  \
# 20626              397             2388            100.0            38.49
# 20627              395             2388            100.0            38.30
# 20628              398             2388            100.0            38.44
# 20629              395             2388            100.0            38.29
# 20630              396             2388            100.0            38.37
#
#        SensorMeasure21  labels
# 20626          22.9735       2
# 20627          23.1594       2
# 20628          22.9333       2
# 20629          23.0640       2
# 20630          23.0522       2
#
# [5 rows x 26 columns]

# %%
data_frame.isnull().sum()
# Out:
# Cycle              0
# OpSet1             0
# OpSet2             0
# OpSet3             0
# SensorMeasure1     0
# SensorMeasure2     0
# SensorMeasure3     0
# SensorMeasure4     0
# SensorMeasure5     0
# SensorMeasure6     0
# SensorMeasure7     0
# SensorMeasure8     0
# SensorMeasure9     0
# SensorMeasure10    0
# SensorMeasure11    0
# SensorMeasure12    0
# SensorMeasure13    0
# SensorMeasure14    0
# SensorMeasure15    0
# SensorMeasure16    0
# SensorMeasure17    0
# SensorMeasure18    0
# SensorMeasure19    0
# SensorMeasure20    0
# SensorMeasure21    0
# labels             0
# dtype: int64

# %% [markdown]
# #### 0 ---> Early Stage of Deterioration
# #### 1 ---> Mid Stage of Deterioration
# #### 2 ---> End Stage of Deterioration

# %%
data_frame['labels'].value_counts()
# Out:
# 0    12338
# 2     4163
# 1     4130
# Name: labels, dtype: int64

# %%
data_frame.describe()
# Out:
#               Cycle        OpSet1        OpSet2   OpSet3  SensorMeasure1  \
# count  20631.000000  20631.000000  20631.000000  20631.0        20631.00
# mean     108.807862     -0.000009      0.000002    100.0          518.67
# std       68.880990      0.002187      0.000293      0.0            0.00
# min        1.000000     -0.008700     -0.000600    100.0          518.67
# 25%       52.000000     -0.001500     -0.000200    100.0          518.67
# 50%      104.000000      0.000000      0.000000    100.0          518.67
# 75%      156.000000      0.001500      0.000300    100.0          518.67
# max      362.000000      0.008700      0.000600    100.0          518.67
#
#        SensorMeasure2  SensorMeasure3  SensorMeasure4  SensorMeasure5  \
# count    20631.000000    20631.000000    20631.000000    2.063100e+04
# mean       642.680934     1590.523119     1408.933782    1.462000e+01
# std          0.500053        6.131150        9.000605    1.776400e-15
# min        641.210000     1571.040000     1382.250000    1.462000e+01
# 25%        642.325000     1586.260000     1402.360000    1.462000e+01
# 50%        642.640000     1590.100000     1408.040000    1.462000e+01
# 75%        643.000000     1594.380000     1414.555000    1.462000e+01
# max        644.530000     1616.910000     1441.490000    1.462000e+01
#
#        SensorMeasure6  ...  SensorMeasure13  SensorMeasure14  SensorMeasure15  \
# count    20631.000000  ...     20631.000000     20631.000000     20631.000000
# mean        21.609803  ...      2388.096152      8143.752722         8.442146
# std          0.001389  ...         0.071919        19.076176         0.037505
# min         21.600000  ...      2387.880000      8099.940000         8.324900
# 25%         21.610000  ...      2388.040000      8133.245000         8.414900
# 50%         21.610000  ...      2388.090000      8140.540000         8.438900
# 75%         21.610000  ...      2388.140000      8148.310000         8.465600
# max         21.610000  ...      2388.560000      8293.720000         8.584800
#
#        SensorMeasure16  SensorMeasure17  SensorMeasure18  SensorMeasure19  \
# count     2.063100e+04     20631.000000          20631.0          20631.0
# mean      3.000000e-02       393.210654           2388.0            100.0
# std       1.387812e-17         1.548763              0.0              0.0
# min       3.000000e-02       388.000000           2388.0            100.0
# 25%       3.000000e-02       392.000000           2388.0            100.0
# 50%       3.000000e-02       393.000000           2388.0            100.0
# 75%       3.000000e-02       394.000000           2388.0            100.0
# max       3.000000e-02       400.000000           2388.0            100.0
#
#        SensorMeasure20  SensorMeasure21        labels
# count     20631.000000     20631.000000  20631.000000
# mean         38.816271        23.289705      0.603752
# std           0.180746         0.108251      0.801769
# min          38.140000        22.894200      0.000000
# 25%          38.700000        23.221800      0.000000
# 50%          38.830000        23.297900      0.000000
# 75%          38.950000        23.366800      1.000000
# max          39.430000        23.618400      2.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# #### Concatenate all the training csv files

# %%
d1 = pd.read_csv('NASA-s-Turbo-Engine-Remaining-Useful-Life-prediction-using-machine-learning-main\Training_1_all_features.csv')
d2 = pd.read_csv('NASA-s-Turbo-Engine-Remaining-Useful-Life-prediction-using-machine-learning-main\Training_2_all_features.csv')
d3 = pd.read_csv('NASA-s-Turbo-Engine-Remaining-Useful-Life-prediction-using-machine-learning-main\Training_3_all_features.csv')
d4 = pd.read_csv('NASA-s-Turbo-Engine-Remaining-Useful-Life-prediction-using-machine-learning-main\Training_4_all_features.csv')

# %%
data_frame = pd.concat([d1,d2,d3,d4])

# %%
data_frame.shape
# Out:
# (160359, 26)

# %%
data_frame.isnull().sum()
# Out:
# Cycle              0
# OpSet1             0
# OpSet2             0
# OpSet3             0
# SensorMeasure1     0
# SensorMeasure2     0
# SensorMeasure3     0
# SensorMeasure4     0
# SensorMeasure5     0
# SensorMeasure6     0
# SensorMeasure7     0
# SensorMeasure8     0
# SensorMeasure9     0
# SensorMeasure10    0
# SensorMeasure11    0
# SensorMeasure12    0
# SensorMeasure13    0
# SensorMeasure14    0
# SensorMeasure15    0
# SensorMeasure16    0
# SensorMeasure17    0
# SensorMeasure18    0
# SensorMeasure19    0
# SensorMeasure20    0
# SensorMeasure21    0
# labels             0
# dtype: int64

# %%
X = data_frame.iloc[:,0:25]

# %%
X.head()
# Out:
#    Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 0      1 -0.0007 -0.0004   100.0          518.67          641.82
# 1      2  0.0019 -0.0003   100.0          518.67          642.15
# 2      3 -0.0043  0.0003   100.0          518.67          642.35
# 3      4  0.0007  0.0000   100.0          518.67          642.35
# 4      5 -0.0019 -0.0002   100.0          518.67          642.37
#
#    SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# 0         1589.70         1400.60           14.62           21.61  ...
# 1         1591.82         1403.14           14.62           21.61  ...
# 2         1587.99         1404.20           14.62           21.61  ...
# 3         1582.79         1401.87           14.62           21.61  ...
# 4         1582.85         1406.22           14.62           21.61  ...
#
#    SensorMeasure12  SensorMeasure13  SensorMeasure14  SensorMeasure15  \
# 0           521.66          2388.02          8138.62           8.4195
# 1           522.28          2388.07          8131.49           8.4318
# 2           522.42          2388.03          8133.23           8.4178
# 3           522.86          2388.08          8133.83           8.3682
# 4           522.19          2388.04          8133.80           8.4294
#
#    SensorMeasure16  SensorMeasure17  SensorMeasure18  SensorMeasure19  \
# 0             0.03              392             2388            100.0
# 1             0.03              392             2388            100.0
# 2             0.03              390             2388            100.0
# 3             0.03              392             2388            100.0
# 4             0.03              393             2388            100.0
#
#    SensorMeasure20  SensorMeasure21
# 0            39.06          23.4190
# 1            39.00          23.4236
# 2            38.95          23.3442
# 3            38.88          23.3739
# 4            38.90          23.4044
#
# [5 rows x 25 columns]

# %%
Y = data_frame['labels']

# %%
Y.value_counts()
# Out:
# 0    95933
# 2    32348
# 1    32078
# Name: labels, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,shuffle=True,stratify=Y,random_state=35)

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
RF.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### At this point it seems like the Model is subject to overfitting

# %%
train_pred = RF.predict(X_train)
train_acc_score = accuracy_score(Y_train,train_pred)
print(train_acc_score)
# Out:
# 0.9999821827867903

# %%
test_pred = RF.predict(X_test)
test_acc_score = accuracy_score(Y_test,test_pred)
print(test_acc_score)
# Out:
# 0.8920761619689033

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(Y_test,test_pred)
print(cnf_matrix)
# Out:
# [[27184  1574    22]
#  [ 1805  7046   772]
#  [    1  1018  8686]]

# %%
import seaborn as sns
class_names=['0','1','2'] # name  of classes
fig, ax = plt.subplots(figsize=(6, 6))
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g',square=True)
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion Matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 355.0, 'Predicted label')

# %%
from sklearn import metrics

# %%
print("Accuracy:",'%.4f' % metrics.accuracy_score(Y_test, test_pred))
print("Precision:",'%.4f' %metrics.precision_score(Y_test, test_pred,average = 'weighted'))
print("Recall:",'%.4f' %metrics.recall_score(Y_test, test_pred,average = 'weighted'))
print("F1 Score:",'%.4f' %metrics.f1_score(Y_test, test_pred,average = 'weighted'))
print(metrics.precision_recall_fscore_support(Y_test, test_pred,average = 'weighted'))
# Out:
# Accuracy: 0.8921
# Precision: 0.8920
# Recall: 0.8921
# F1 Score: 0.8920
# (0.8920402331726414, 0.8920761619689033, 0.8920255405854, None)
